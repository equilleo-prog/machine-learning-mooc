# %% [markdown]
# # 📝 Exercise M1.02
#
# The goal of this exercise is to fit a similar model as in the previous
# notebook to get familiar with manipulating scikit-learn objects and in
# particular the `.fit/.predict/.score` API.

# %% [markdown]
# Let's load the adult census dataset with only numerical variables.

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

adult_census = pd.read_csv("../datasets/adult-census-numeric.csv")
data = adult_census.drop(columns="class")
target = adult_census["class"]

# %% [markdown]
# Create a `KNeighborsClassifier` model with `n_neighbors=50`. Fit this model on the data and target loaded above

# %%
model = KNeighborsClassifier(n_neighbors=50) 
_ = model.fit(data, target)

# %% [markdown]
# Use your model to make predictions on the first 10 data points inside the
# data. Do they match the actual target values?

# %%
target_predicted = model.predict(data[:10]) # make predictions

print("target_predicted : ", target_predicted, " / target : ", list(target[:10]))
print("average success rate : ", (target[:10] == target_predicted).mean())# average success rate
# Out:
# target_predicted :  [' <=50K' ' <=50K' ' <=50K' ' <=50K' ' <=50K' ' <=50K' ' <=50K' ' >50K'
#  ' <=50K' ' <=50K']  / target :  [' <=50K', ' <=50K', ' <=50K', ' <=50K', ' <=50K', ' <=50K', ' <=50K', ' >50K', ' <=50K', ' >50K']
# average success rate :  0.9

# %% [markdown]
# Compute the accuracy on the training data.

# %%
accuracy = model.score(data, target)
model_name = model.__class__.__name__
print(f"The test accuracy using a {model_name} is {accuracy:.3f}")
# Out:
# The test accuracy using a KNeighborsClassifier is 0.829

# %% [markdown]
# Now load the test data from `"../datasets/adult-census-numeric-test.csv"` and
# compute the accuracy on the test data.

# %%
adult_census_test = pd.read_csv("../datasets/adult-census-numeric-test.csv")
data_test = adult_census_test.drop(columns="class")
target_test = adult_census_test["class"]

accuracy = model.score(data_test, target_test)
model_name = model.__class__.__name__

print(f"The test accuracy using a {model_name} is {accuracy:.3f}")
# Out:
# The test accuracy using a KNeighborsClassifier is 0.819

# %% [markdown]
# <span style="color:green">= slight overfitting (trouble to generalize) because accuracy on testing set is higher than accuracy on training set </span>
